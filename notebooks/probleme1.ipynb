# %% [markdown]
# #Problème n°1

# %% [markdown]
# La bonne transmission de signaux électromagnétiques dans l'atmosphère peut dépendre de la météo. La pluie affecte notoirement les échanges entre les antennes relais des réseaux mobiles actuels. C'est une gêne, mais aussi une opportunité: l'atténuation des ondes électromagnétiques due à la pluie peut être mesurée et utilisée comme un moyen de quantifier les précipitations.
#
# Dans ce problème, on s'intéresse à la conversion de l'atténuation, définie comme un rapport entre puissance émise et puissance reçue et exprimée en dB, en un taux de pluie moyen le long de segments physiques dont les extrémités sont des paires d'antennes relais.
#
# Evidemment, d'autres éléments que le pluie, plus ou moins bien connus, peuvent influencer l'atténuation. La simulation sur laquelle nous allons travailler, qui porte sur un millier de paires d'antennes virtuelles, est construite de la façon suivante:
#
# - pour une paire d'antennes donnée, on modélise une série temporelle de taux de pluie moyen par un processus stochastique dont les paramètres dépendent entre autres de la distance qui sépare les antennes.
# - pour en tirer des atténuations, on applique à cette série les transformations suivantes:
#     - un filtre convolutif, censé modéliser l'impact du film d'eau se formant sur les antennes au cours d'un épisode de pluie.
#     - une conversion non-linéaire, tirée d'un modèle physique, est appliquée composante à composante.
#  épisode pluvieux (ce film qui s'épaissit augmente progressivement l'atténuation).
#     - un bruit haute-fréquence
#     - un bruit basse fréquence
#
# La cellules suivantes permettent de récupérer les briques de code utiles, de construire un dictionnaire contenant des identifiants de paires d'antennes (clefs) et les distances les séparant (valeurs). La dernière cellule montre des exemples de séries temporelles simulées pour quelques paires.

# %%
# Local clone
! git clone https://github.com/Corentin312/exam_2025.git
! cp exam_2025/utils/utils_probleme1.py .
# Out:
# Cloning into 'exam_2025'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 75 (delta 9), reused 4 (delta 4), pack-reused 58 (from 1)
# Receiving objects: 100% (75/75), 1.42 MiB | 13.88 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# Imports
from os.path import join, isdir, isfile
from os import listdir as ls
import copy
import torch
import numpy as np
import sys
from utils_probleme1 import create_dataloader

# %%
# Dictionnaire des "distances" (générées au hasard)
idx2distance_train = {i: 0.2 +  1.8 * torch.rand((1,)).item() for i in range(0, 1000)}
idx2distance_val = {i: 0.2 +  1.8 * torch.rand((1,)).item() for i in range(1000, 1200)}

# Paramètres de la simulation
duration = 4096  # durée de la série temporelle (unité : minutes)
batch_size = 100  # taille d'un échantillon

# Création du dataloader (il contient toutes les étapes de la simulation)
# (en une époque, chaque paire d'antennes du dictionnaire idx2distance
# a été tirée exactement une fois)
trainloader = create_dataloader(duration, idx2distance_train, batch_size)

# Génération d'un batch contenant des séries temporelles
for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
    break

# %%
import matplotlib.pyplot as plt

for k in range(5):
  plt.figure(figsize=(10, 6))
  plt.plot(np.arange(duration), rain_rates[k], label='rain rates')
  plt.plot(np.arange(duration), attenuations[k], label='attenuations')
  plt.title(f"Attenuations et taux de pluie moyen pour la paire n°{ids[k].item():.0f} (distance: {dists[k].item():.2f} km)")
  plt.xlabel('Time (minutes)')
  plt.ylabel('DB (atten.) ou mm/h (pluie)')
  plt.ylim(-1,6)
  plt.legend()
  plt.show()

# %% [markdown]
# ## Partie I : Un réseau de neurones générique

# %% [markdown]
# # A partir des briques de base

# %% [markdown]
# Dans cette partie, on entraîne un UNet1D à faire le lien entre atténuations
# et taux de pluie. Les cellules suivantes contiennent les blocs du UNet1D et son montage :

# %%
##############################################################################################
################################     UNet 1D building blokcs    ##############################
import torch
import torch.nn as nn
import torch.nn.functional as F

class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv1d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x

class Down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(Down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool1d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class Up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=False):
        super(Up, self).__init__()
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear')
        else:
            self.up = nn.ConvTranspose1d(in_ch, in_ch, kernel_size=2, stride=2)

        self.conv = double_conv(2*in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x1.size()[2] - x2.size()[2]
        x2 = F.pad(x2, (diffX // 2, int(diffX / 2)))

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv1d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x


################################################################################
######################################## class UNet1D ##########################

class UNet1D(nn.Module):
    def __init__(self, n_channels, n_classes, size=64):
        super(UNet1D, self).__init__()
        self.inc = inconv(n_channels, size)
        self.down1 = Down(size, 2*size)
        self.down2 = Down(2*size, 4*size)
        self.down3 = Down(4*size, 8*size)
        self.down4 = Down(8*size, 8*size)
        self.up1 = Up(8*size, 4*size)
        self.up2 = Up(4*size, 2*size)
        self.up3 = Up(2*size, size)
        self.up4 = Up(size, size)
        self.outc = outconv(size, n_classes)
        self.n_classes=n_classes

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        del x4, x5
        x = self.up2(x, x3)
        del x3
        x = self.up3(x, x2)
        del x2
        x = self.up4(x, x1)
        del x1
        x = self.outc(x)
        return   x

# %% [markdown]
# **Consignes:** \
# 1) Entraîner sur GPU un UNet 1D à restituer les taux de pluie à partir des atténuations.
# - On utilisera la MSE comme fonction de coût et comme score. Dans les deux cas, prendre une marge de deux heures au début et à la fin de la série temporelle pour éviter les effets de bord.
# - La descente de gradient stochastique sera pilotée par l'optimiseur ADAM (paramétrage standard) sur cinquante époques.
#
# 2) Tracer la courbe d'apprentissage de manière à montrer l'évolution:
# - des performances en généralisation sur de nouvelles données issues des paires d'antennes vues à l'entraînement.
# - des performances en généralisation sur des séries issues de paires d'antennes indépendantes (celles de *idx2distance_val*).
#
#
# 3) Visualiser les prédictions après apprentissage

# %%
n_channels = 1
n_classes = 1
model = UNet1D(n_channels, n_classes, size=32)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters())

# Training loop
num_epochs = 50
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_loss = 0.0
    for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
        attenuations = attenuations.unsqueeze(1).to(device)  # Add channel dimension
        rain_rates = rain_rates.unsqueeze(1).to(device)  # Add channel dimension

        optimizer.zero_grad()
        outputs = model(attenuations)
        loss = criterion(outputs[:, :, 120:-120], rain_rates[:, :, 120:-120])  # Margin of 2 hours
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(trainloader))

    # Validation phase
    model.eval()
    val_loss = 0.0
    valloader = create_dataloader(duration, idx2distance_val, batch_size)
    with torch.no_grad():
        for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(valloader):
            attenuations = attenuations.unsqueeze(1).to(device)  # Add channel dimension
            rain_rates = rain_rates.unsqueeze(1).to(device)  # Add channel dimension

            outputs = model(attenuations)
            loss = criterion(outputs[:, :, 120:-120], rain_rates[:, :, 120:-120])  # Margin of 2 hours
            val_loss += loss.item()

    val_losses.append(val_loss / len(valloader))

    print(f"Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_losses[-1]:.4f} Val Loss: {val_losses[-1]:.4f}")

# Plot the learning curves
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()

# Visualize predictions (example)
with torch.no_grad():
    for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
        attenuations = attenuations.unsqueeze(1).to(device)
        outputs = model(attenuations)
        break  # Take only one batch for visualization

for k in range(5):
    plt.figure(figsize=(10, 6))
    plt.plot(rain_rates[k].cpu().numpy(), label='True Rain Rates')
    plt.plot(outputs[k, 0].cpu().numpy(), label='Predicted Rain Rates')
    plt.title(f"Rain Rate Prediction for Pair {ids[k].item()}")
    plt.xlabel('Time (minutes)')
    plt.ylabel('Rain Rate')
    plt.legend()
    plt.show()
# Out:
# Epoch [1/50] Train Loss: 0.4573 Val Loss: 0.7592
# Epoch [2/50] Train Loss: 0.1961 Val Loss: 0.7562
# Epoch [3/50] Train Loss: 0.1616 Val Loss: 0.5899
# Epoch [4/50] Train Loss: 0.1509 Val Loss: 0.4410
# Epoch [5/50] Train Loss: 0.1439 Val Loss: 0.2360
# Epoch [6/50] Train Loss: 0.1445 Val Loss: 0.1663
# Epoch [7/50] Train Loss: 0.1380 Val Loss: 0.1533
# Epoch [8/50] Train Loss: 0.1392 Val Loss: 0.1405
# Epoch [9/50] Train Loss: 0.1372 Val Loss: 0.1525
# Epoch [10/50] Train Loss: 0.1379 Val Loss: 0.1533
# Epoch [11/50] Train Loss: 0.1342 Val Loss: 0.1501
# Epoch [12/50] Train Loss: 0.1370 Val Loss: 0.1511
# Epoch [13/50] Train Loss: 0.1354 Val Loss: 0.1332
# Epoch [14/50] Train Loss: 0.1341 Val Loss: 0.1388
# Epoch [15/50] Train Loss: 0.1324 Val Loss: 0.1393
# Epoch [16/50] Train Loss: 0.1316 Val Loss: 0.1335
# Epoch [17/50] Train Loss: 0.1348 Val Loss: 0.1346
# Epoch [18/50] Train Loss: 0.1341 Val Loss: 0.1403
# Epoch [19/50] Train Loss: 0.1310 Val Loss: 0.1458
# Epoch [20/50] Train Loss: 0.1324 Val Loss: 0.1383
# Epoch [21/50] Train Loss: 0.1329 Val Loss: 0.1361
# Epoch [22/50] Train Loss: 0.1316 Val Loss: 0.1356
# Epoch [23/50] Train Loss: 0.1315 Val Loss: 0.1261
# Epoch [24/50] Train Loss: 0.1306 Val Loss: 0.1396
# Epoch [25/50] Train Loss: 0.1309 Val Loss: 0.1430
# Epoch [26/50] Train Loss: 0.1317 Val Loss: 0.1277
# Epoch [27/50] Train Loss: 0.1296 Val Loss: 0.1352
# Epoch [28/50] Train Loss: 0.1302 Val Loss: 0.1345
# Epoch [29/50] Train Loss: 0.1298 Val Loss: 0.1349
# Epoch [30/50] Train Loss: 0.1307 Val Loss: 0.1371
# Epoch [31/50] Train Loss: 0.1320 Val Loss: 0.1356
# Epoch [32/50] Train Loss: 0.1293 Val Loss: 0.1363
# Epoch [33/50] Train Loss: 0.1319 Val Loss: 0.1279
# Epoch [34/50] Train Loss: 0.1325 Val Loss: 0.1374
# Epoch [35/50] Train Loss: 0.1316 Val Loss: 0.1361
# Epoch [36/50] Train Loss: 0.1318 Val Loss: 0.1308
# Epoch [37/50] Train Loss: 0.1293 Val Loss: 0.1333
# Epoch [38/50] Train Loss: 0.1320 Val Loss: 0.1291
# Epoch [39/50] Train Loss: 0.1299 Val Loss: 0.1290
# Epoch [40/50] Train Loss: 0.1288 Val Loss: 0.1347
# Epoch [41/50] Train Loss: 0.1311 Val Loss: 0.1324
# Epoch [42/50] Train Loss: 0.1304 Val Loss: 0.1369
# Epoch [43/50] Train Loss: 0.1282 Val Loss: 0.1353
# Epoch [44/50] Train Loss: 0.1296 Val Loss: 0.1328
# Epoch [45/50] Train Loss: 0.1324 Val Loss: 0.1399
# Epoch [46/50] Train Loss: 0.1273 Val Loss: 0.1359
# Epoch [47/50] Train Loss: 0.1292 Val Loss: 0.1409
# Epoch [48/50] Train Loss: 0.1286 Val Loss: 0.1316
# Epoch [49/50] Train Loss: 0.1271 Val Loss: 0.1358
# Epoch [50/50] Train Loss: 0.1283 Val Loss: 0.1368

# %% [markdown]
# ## Partie II
#
# Dans la première partie, le modèle était générique: la specificité de la paire d'antenne n'était pas prise en compte. On se propose de le faire en combinant un réseau générique à un perceptron spécifique, de sorte que la sortie $Z$ s'exprime sous la forme: \
# $$Z = F(X, k) = f^{\tiny{Perceptron}}_{\alpha_k}(f^{\tiny{UNet}}_{\theta}(X))$$ \
#  où $f^{\tiny{UNet}}_{\theta}(.)$ représente la fonction *forward* d'un UNet et $f^{\tiny{Perceptron}}_{\alpha_k}(.)$, la fonction forward du perceptron associé à la paire d'antennes d'identifiant $k$. \
#
# Il s'agit donc en premier lieu d'adjoindre au UNet de la partie I autant de perceptrons que le jeu d'entraînement compte de paires d'antennes, ce qui se fait grâce aux lignes suivantes:

# %%
# Pour l'ajout de 1200 perceptrons à deux couches:
self.num_pairs = 1200
self.input_size_fc_layer = 5
self.hidden_size_fc_layer = 5
# Liste des premières couches
self.linears1 = nn.ModuleList([nn.Linear(self.input_size_fc_layer,
                                         self.hidden_size_fc_layer) for i in range(self.num_pairs)])
# Liste des secondes couches
self.linears2 = nn.ModuleList([nn.Linear(self.hidden_size_fc_layer,
                                         1) for i in range(self.num_pairs)])

# %% [markdown]
# **Consignes:** \
# 1) Définir une nouvelle classe de réseau en modifiant la classe UNet1D (dans utils_probleme1.py).
# Ajouter ces perceptrons au réseau.
#
# 2) Fixer *self.n_classes* de façon à ce que la sortie du UNet soit compatible avec l'entrée du perceptron.
#
# 3) Modifications de la fonction forward:
# - elle doit prendre comme arguments un batch d'entrées et un batch d'identifiants.
#
# - après les étapes propres au UNet, elle doit appliquer le perceptron d'indice k à une série provenant de la paire n°k. La cellule de code suivante fournit un exemple dont on pourra directement s'inspirer.
#
# 4) Suivre les performances en généralisation sur les paires d'antennes du jeu d'entraînement et sur les deux cents paires de validation. Commenter.

# %%
################################################################################
######################################## class UNet1D ##########################

class UNet1D(nn.Module):
    def __init__(self, n_channels, n_classes, size=64):
        super(UNet1D, self).__init__()
        self.inc = inconv(n_channels, size)
        self.down1 = Down(size, 2*size)
        self.down2 = Down(2*size, 4*size)
        self.down3 = Down(4*size, 8*size)
        self.down4 = Down(8*size, 8*size)
        self.up1 = Up(8*size, 4*size)
        self.up2 = Up(4*size, 2*size)
        self.up3 = Up(2*size, size)
        self.up4 = Up(size, size)
        # Modification pour la partie 2 : n_classes = 5
        self.n_classes = 5
        self.outc = outconv(size, self.n_classes)
        # Ajout des perceptrons pour la partie 2
        self.num_pairs = 1200
        self.input_size_fc_layer = 5
        self.hidden_size_fc_layer = 5
        self.linears1 = nn.ModuleList([nn.Linear(self.input_size_fc_layer,
                                                 self.hidden_size_fc_layer) for i in range(self.num_pairs)])
        self.linears2 = nn.ModuleList([nn.Linear(self.hidden_size_fc_layer,
                                                 1) for i in range(self.num_pairs)])
        self.relu = nn.ReLU()

    def apply_perceptron(self, UNet_output, ids):
      for i in range(ids.shape[0]):
          id = ids[i]
          # application de la première couche
          x = self.linears1[id](UNet_output[i].transpose(0,1).contiguous())
          x = self.relu(x)
          # application de la seconde couche
          x = self.linears2[id](x)
          # correction multiplicative de UNet_output
          UNet_output[i, 0] *= 1 + x.transpose(0,1).contiguous().squeeze(0)
      return UNet_output[:,0]

    def forward(self, x, ids):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        del x4, x5
        x = self.up2(x, x3)
        del x3
        x = self.up3(x, x2)
        del x2
        x = self.up4(x, x1)
        del x1
        x = self.outc(x)
        # Application de la fonction apply_perceptron
        x = self.apply_perceptron(x, ids)
        return x

# %%
# Initialisation du modèle, du critère et de l'optimiseur
n_channels = 1
n_classes = 1  # On garde n_classes = 1, car la sortie finale est un taux de pluie
model = UNet1D(n_channels, n_classes, size=32)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters())

# Boucle d'entraînement
num_epochs = 50
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # Phase d'entraînement
    model.train()
    running_loss = 0.0
    for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
        attenuations = attenuations.unsqueeze(1).to(device)
        rain_rates = rain_rates.unsqueeze(1).to(device)
        ids = ids.to(device)  # Déplacer les identifiants sur le GPU

        optimizer.zero_grad()
        outputs = model(attenuations, ids)  # Appeler le modèle avec les identifiants
        loss = criterion(outputs[:, 120:-120], rain_rates[:, 0, 120:-120])  # Calcul de la perte avec une marge de 2 heures
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(trainloader))

    # Phase de validation
    model.eval()
    val_loss = 0.0
    valloader = create_dataloader(duration, idx2distance_val, batch_size)
    with torch.no_grad():
        for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(valloader):
            attenuations = attenuations.unsqueeze(1).to(device)
            rain_rates = rain_rates.unsqueeze(1).to(device)
            ids = ids.to(device)  # Déplacer les identifiants sur le GPU

            outputs = model(attenuations, ids)  # Appeler le modèle avec les identifiants
            loss = criterion(outputs[:, 120:-120], rain_rates[:, 0, 120:-120])  # Calcul de la perte avec une marge de 2 heures
            val_loss += loss.item()

    val_losses.append(val_loss / len(valloader))

    print(f"Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_losses[-1]:.4f} Val Loss: {val_losses[-1]:.4f}")

# Tracé des courbes d'apprentissage
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()
# Out:
# Epoch [1/50] Train Loss: 0.7085 Val Loss: 0.9469
# Epoch [2/50] Train Loss: 0.3252 Val Loss: 0.9593
# Epoch [3/50] Train Loss: 0.2362 Val Loss: 0.8101
# Epoch [4/50] Train Loss: 0.2219 Val Loss: 0.8427
# Epoch [5/50] Train Loss: 0.2181 Val Loss: 0.3428
# Epoch [6/50] Train Loss: 0.2100 Val Loss: 0.2637
# Epoch [7/50] Train Loss: 0.2115 Val Loss: 0.2362
# Epoch [8/50] Train Loss: 0.2072 Val Loss: 0.2364
# Epoch [9/50] Train Loss: 0.2041 Val Loss: 0.2332
# Epoch [10/50] Train Loss: 0.2003 Val Loss: 0.2188
# Epoch [11/50] Train Loss: 0.1977 Val Loss: 0.2275
# Epoch [12/50] Train Loss: 0.1956 Val Loss: 0.2406
# Epoch [13/50] Train Loss: 0.1967 Val Loss: 0.2257
# Epoch [14/50] Train Loss: 0.1926 Val Loss: 0.2453
# Epoch [15/50] Train Loss: 0.1924 Val Loss: 0.2428
# Epoch [16/50] Train Loss: 0.1937 Val Loss: 0.2334
# Epoch [17/50] Train Loss: 0.1881 Val Loss: 0.2243
# Epoch [18/50] Train Loss: 0.1892 Val Loss: 0.2120
# Epoch [19/50] Train Loss: 0.1871 Val Loss: 0.2383
# Epoch [20/50] Train Loss: 0.1912 Val Loss: 0.2278
# Epoch [21/50] Train Loss: 0.1829 Val Loss: 0.2257
# Epoch [22/50] Train Loss: 0.1826 Val Loss: 0.2328
# Epoch [23/50] Train Loss: 0.1797 Val Loss: 0.2279
# Epoch [24/50] Train Loss: 0.1782 Val Loss: 0.2255
# Epoch [25/50] Train Loss: 0.1818 Val Loss: 0.2375
# Epoch [26/50] Train Loss: 0.1783 Val Loss: 0.2240
# Epoch [27/50] Train Loss: 0.1743 Val Loss: 0.2207
# Epoch [28/50] Train Loss: 0.1719 Val Loss: 0.2295
# Epoch [29/50] Train Loss: 0.1705 Val Loss: 0.2284
# Epoch [30/50] Train Loss: 0.1731 Val Loss: 0.2297
# Epoch [31/50] Train Loss: 0.1722 Val Loss: 0.2317
# Epoch [32/50] Train Loss: 0.1710 Val Loss: 0.2311
# Epoch [33/50] Train Loss: 0.1653 Val Loss: 0.2376
# Epoch [34/50] Train Loss: 0.1667 Val Loss: 0.2340
# Epoch [35/50] Train Loss: 0.1658 Val Loss: 0.2359
# Epoch [36/50] Train Loss: 0.1646 Val Loss: 0.2316
# Epoch [37/50] Train Loss: 0.1664 Val Loss: 0.2522
# Epoch [38/50] Train Loss: 0.1641 Val Loss: 0.2471
# Epoch [39/50] Train Loss: 0.1598 Val Loss: 0.2319
# Epoch [40/50] Train Loss: 0.1579 Val Loss: 0.2322
# Epoch [41/50] Train Loss: 0.1572 Val Loss: 0.2350
# Epoch [42/50] Train Loss: 0.1553 Val Loss: 0.2260
# Epoch [43/50] Train Loss: 0.1532 Val Loss: 0.2344
# Epoch [44/50] Train Loss: 0.1547 Val Loss: 0.2457
# Epoch [45/50] Train Loss: 0.1535 Val Loss: 0.2397
# Epoch [46/50] Train Loss: 0.1518 Val Loss: 0.2699
# Epoch [47/50] Train Loss: 0.1487 Val Loss: 0.2477
# Epoch [48/50] Train Loss: 0.1498 Val Loss: 0.2526
# Epoch [49/50] Train Loss: 0.1496 Val Loss: 0.2542
# Epoch [50/50] Train Loss: 0.1482 Val Loss: 0.2329

# %% [markdown]
# On voit que la train loss est equivalente, mais la validation loss est plus grande. La raison est expliquée en partie 3

# %% [markdown]
# ## Partie III
#
# La solution proposée dans la partie II a un défaut: les performances chutent sur les paires d'antennes qui n'ont pas été rencontrées pendant l'entraînement. Pour le corriger, on se propose de suivre la méthode suivante:
# - ajouter un perceptron "générique" de même architecture que les perceptrons spécifiques.
# - entraîner le réseau de la partie II en remplaçant une fois sur quatre l'identifiant de la paire d'antennes par l'indice du perceptron générique.
# - après cinquante époques, geler les poids de la partie générique et prolonger l'apprentissage des perceptrons spécifiques sur une vingtaine d'époque.
#
# **Consignes:** \
#
# 1) Mettre en oeuvre cette méthode
#
# 2) Conclure sur son efficacité

# %%
class UNet1D(nn.Module):
    def __init__(self, n_channels, n_classes, size=64):
        super(UNet1D, self).__init__()
        self.inc = inconv(n_channels, size)
        self.down1 = Down(size, 2 * size)
        self.down2 = Down(2 * size, 4 * size)
        self.down3 = Down(4 * size, 8 * size)
        self.down4 = Down(8 * size, 8 * size)
        self.up1 = Up(8 * size, 4 * size)
        self.up2 = Up(4 * size, 2 * size)
        self.up3 = Up(2 * size, size)
        self.up4 = Up(size, size)
        self.n_classes = 5
        self.outc = outconv(size, self.n_classes)

        # Perceptrons spécifiques + perceptron générique
        self.num_pairs = 1201  # 1200 spécifiques + 1 générique
        self.generic_perceptron_id = 1200
        self.input_size_fc_layer = 5
        self.hidden_size_fc_layer = 5
        self.linears1 = nn.ModuleList([nn.Linear(self.input_size_fc_layer,
                                                 self.hidden_size_fc_layer) for i in range(self.num_pairs)])
        self.linears2 = nn.ModuleList([nn.Linear(self.hidden_size_fc_layer,
                                                 1) for i in range(self.num_pairs)])
        self.relu = nn.ReLU()

    def apply_perceptron(self, UNet_output, ids):
        for i in range(ids.shape[0]):
            id = ids[i]
            x = self.linears1[id](UNet_output[i].transpose(0, 1).contiguous())
            x = self.relu(x)
            x = self.linears2[id](x)
            UNet_output[i, 0] *= 1 + x.transpose(0, 1).contiguous().squeeze(0)
        return UNet_output[:, 0]

    def forward(self, x, ids):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        del x4, x5
        x = self.up2(x, x3)
        del x3
        x = self.up3(x, x2)
        del x2
        x = self.up4(x, x1)
        del x1
        x = self.outc(x)
        x = self.apply_perceptron(x, ids)
        return x


# Initialisation du modèle, du critère et de l'optimiseur
n_channels = 1
n_classes = 1
model = UNet1D(n_channels, n_classes, size=32)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters())

# Boucle d'entraînement
num_epochs = 70  # Total epochs (50 + 20)
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    # Training phase
    model.train()
    running_loss = 0.0
    for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
        attenuations = attenuations.unsqueeze(1).to(device)
        rain_rates = rain_rates.unsqueeze(1).to(device)
        ids = ids.to(device)

        # Replacing ids with generic perceptron ID once every four times
        if epoch < 50 and batch_idx % 4 == 0:
            ids = torch.full_like(ids, model.generic_perceptron_id, device=ids.device)

        optimizer.zero_grad()
        outputs = model(attenuations, ids)
        loss = criterion(outputs[:, 120:-120], rain_rates[:, 0, 120:-120])
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_losses.append(running_loss / len(trainloader))

    # Validation phase
    model.eval()
    val_loss = 0.0
    valloader = create_dataloader(duration, idx2distance_val, batch_size)
    with torch.no_grad():
        for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(valloader):
            attenuations = attenuations.unsqueeze(1).to(device)
            rain_rates = rain_rates.unsqueeze(1).to(device)
            ids = ids.to(device)

            outputs = model(attenuations, ids)
            loss = criterion(outputs[:, 120:-120], rain_rates[:, 0, 120:-120])
            val_loss += loss.item()

    val_losses.append(val_loss / len(valloader))

    print(f"Epoch [{epoch + 1}/{num_epochs}] Train Loss: {train_losses[-1]:.4f} Val Loss: {val_losses[-1]:.4f}")

    # Freeze generic perceptron weights after 50 epochs
    if epoch == 50:
        for param in model.linears1[model.generic_perceptron_id].parameters():
            param.requires_grad = False
        for param in model.linears2[model.generic_perceptron_id].parameters():
            param.requires_grad = False

# Tracé des courbes d'apprentissage
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Learning Curves')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()

# Visualize predictions (example)
with torch.no_grad():
    for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
        attenuations = attenuations.unsqueeze(1).to(device)
        outputs = model(attenuations, ids)  # Pass ids to the model
        break  # Take only one batch for visualization

for k in range(5):
    plt.figure(figsize=(10, 6))
    plt.plot(rain_rates[k].cpu().numpy(), label='True Rain Rates')
    plt.plot(outputs[k].cpu().numpy(), label='Predicted Rain Rates')  # Use outputs[k] directly
    plt.title(f"Rain Rate Prediction for Pair {ids[k].item()}")
    plt.xlabel('Time (minutes)')
    plt.ylabel('Rain Rate')
    plt.legend()
    plt.show()
# Out:
# Epoch [1/70] Train Loss: 0.6880 Val Loss: 1.0830
# Epoch [2/70] Train Loss: 0.3923 Val Loss: 1.0613
# Epoch [3/70] Train Loss: 0.2921 Val Loss: 0.8329
# Epoch [4/70] Train Loss: 0.2547 Val Loss: 0.5357
# Epoch [5/70] Train Loss: 0.2389 Val Loss: 0.2922
# Epoch [6/70] Train Loss: 0.2317 Val Loss: 0.2261
# Epoch [7/70] Train Loss: 0.2289 Val Loss: 0.2374
# Epoch [8/70] Train Loss: 0.2282 Val Loss: 0.2335
# Epoch [9/70] Train Loss: 0.2245 Val Loss: 0.2204
# Epoch [10/70] Train Loss: 0.2165 Val Loss: 0.2181
# Epoch [11/70] Train Loss: 0.2206 Val Loss: 0.2520
# Epoch [12/70] Train Loss: 0.2161 Val Loss: 0.2672
# Epoch [13/70] Train Loss: 0.2138 Val Loss: 0.2276
# Epoch [14/70] Train Loss: 0.2055 Val Loss: 0.2309
# Epoch [15/70] Train Loss: 0.1975 Val Loss: 0.2300
# Epoch [16/70] Train Loss: 0.1991 Val Loss: 0.2268
# Epoch [17/70] Train Loss: 0.2045 Val Loss: 0.2406
# Epoch [18/70] Train Loss: 0.1985 Val Loss: 0.2331
# Epoch [19/70] Train Loss: 0.1952 Val Loss: 0.2222
# Epoch [20/70] Train Loss: 0.1957 Val Loss: 0.2227
# Epoch [21/70] Train Loss: 0.1963 Val Loss: 0.2224
# Epoch [22/70] Train Loss: 0.1908 Val Loss: 0.2262
# Epoch [23/70] Train Loss: 0.1917 Val Loss: 0.2361
# Epoch [24/70] Train Loss: 0.1868 Val Loss: 0.2200
# Epoch [25/70] Train Loss: 0.1860 Val Loss: 0.2200
# Epoch [26/70] Train Loss: 0.1847 Val Loss: 0.2219
# Epoch [27/70] Train Loss: 0.1840 Val Loss: 0.2404
# Epoch [28/70] Train Loss: 0.1795 Val Loss: 0.2379
# Epoch [29/70] Train Loss: 0.1737 Val Loss: 0.2309
# Epoch [30/70] Train Loss: 0.1735 Val Loss: 0.2247
# Epoch [31/70] Train Loss: 0.1769 Val Loss: 0.2235
# Epoch [32/70] Train Loss: 0.1830 Val Loss: 0.2240
# Epoch [33/70] Train Loss: 0.1731 Val Loss: 0.2280
# Epoch [34/70] Train Loss: 0.1744 Val Loss: 0.2189
# Epoch [35/70] Train Loss: 0.1694 Val Loss: 0.2250
# Epoch [36/70] Train Loss: 0.1678 Val Loss: 0.2143
# Epoch [37/70] Train Loss: 0.1648 Val Loss: 0.2229
# Epoch [38/70] Train Loss: 0.1707 Val Loss: 0.2318
# Epoch [39/70] Train Loss: 0.1706 Val Loss: 0.2259
# Epoch [40/70] Train Loss: 0.1679 Val Loss: 0.2206
# Epoch [41/70] Train Loss: 0.1699 Val Loss: 0.2266
# Epoch [42/70] Train Loss: 0.1649 Val Loss: 0.2208
# Epoch [43/70] Train Loss: 0.1604 Val Loss: 0.2103
# Epoch [44/70] Train Loss: 0.1643 Val Loss: 0.2205
# Epoch [45/70] Train Loss: 0.1649 Val Loss: 0.2268
# Epoch [46/70] Train Loss: 0.1614 Val Loss: 0.2189
# Epoch [47/70] Train Loss: 0.1645 Val Loss: 0.2145
# Epoch [48/70] Train Loss: 0.1567 Val Loss: 0.2193
# Epoch [49/70] Train Loss: 0.1553 Val Loss: 0.2133
# Epoch [50/70] Train Loss: 0.1538 Val Loss: 0.2174
# Epoch [51/70] Train Loss: 0.1558 Val Loss: 0.2151
# Epoch [52/70] Train Loss: 0.1551 Val Loss: 0.2207
# Epoch [53/70] Train Loss: 0.1559 Val Loss: 0.2110
# Epoch [54/70] Train Loss: 0.1555 Val Loss: 0.2174
# Epoch [55/70] Train Loss: 0.1536 Val Loss: 0.2083
# Epoch [56/70] Train Loss: 0.1507 Val Loss: 0.2110
# Epoch [57/70] Train Loss: 0.1523 Val Loss: 0.2086
# Epoch [58/70] Train Loss: 0.1498 Val Loss: 0.2141
# Epoch [59/70] Train Loss: 0.1496 Val Loss: 0.2169
# Epoch [60/70] Train Loss: 0.1482 Val Loss: 0.2199
# Epoch [61/70] Train Loss: 0.1482 Val Loss: 0.2114
# Epoch [62/70] Train Loss: 0.1448 Val Loss: 0.2213
# Epoch [63/70] Train Loss: 0.1461 Val Loss: 0.2342
# Epoch [64/70] Train Loss: 0.1428 Val Loss: 0.2145
# Epoch [65/70] Train Loss: 0.1435 Val Loss: 0.2240
# Epoch [66/70] Train Loss: 0.1412 Val Loss: 0.2184
# Epoch [67/70] Train Loss: 0.1425 Val Loss: 0.2261
# Epoch [68/70] Train Loss: 0.1415 Val Loss: 0.2227
# Epoch [69/70] Train Loss: 0.1410 Val Loss: 0.2202
# Epoch [70/70] Train Loss: 0.1362 Val Loss: 0.2178

# %% [markdown]
# Les résultats ont l'air meilleurs grâce à la technique mais aussi dû au nombre d'epochs supérieur
